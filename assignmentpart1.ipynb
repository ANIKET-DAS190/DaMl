# %% [markdown]
# Business Problem

# %%
import pandas as pd

# %%
df = pd.read_csv("C://Users//HP//Downloads//in-vehicle-coupon-recommendation.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
df.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %%
df.isna().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
df['Bar'].fillna(df['Bar'].mode()[0], inplace= True)
df['CoffeeHouse'].fillna(df['CoffeeHouse'].mode()[0], inplace= True)
df['CarryAway'].fillna(df['CarryAway'].mode()[0], inplace= True)
df['RestaurantLessThan20'].fillna(df['RestaurantLessThan20'].mode()[0], inplace= True)
df['Restaurant20To50'].fillna(df['Restaurant20To50'].mode()[0], inplace= True)

# %%
df1 = df.drop(['car'], axis =1)

# %%
df1.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       1~3                  4~8              1~3
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()

# %%
df1['income_encoded'] = oe.fit_transform(df1[['income']])

# %%
df1.tail(10)
# Out:
#       destination passanger weather  temperature  time                 coupon  \
# 12674        Home     Alone   Rainy           55  10PM           Coffee House
# 12675        Home     Alone   Snowy           30  10PM           Coffee House
# 12676        Home     Alone   Sunny           80   6PM      Restaurant(20-50)
# 12677        Home   Partner   Sunny           30   6PM        Restaurant(<20)
# 12678        Home   Partner   Sunny           30  10PM        Restaurant(<20)
# 12679        Home   Partner   Rainy           55   6PM  Carry out & Take away
# 12680        Work     Alone   Rainy           55   7AM  Carry out & Take away
# 12681        Work     Alone   Snowy           30   7AM           Coffee House
# 12682        Work     Alone   Snowy           30   7AM                    Bar
# 12683        Work     Alone   Sunny           80   7AM      Restaurant(20-50)
#
#       expiration gender age maritalStatus  ...  CarryAway  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
df1['temperature_scaled'] = sc.fit_transform(df1[['temperature']])

# %%
df1.head(10)
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
# 5  No Urgent Place  Friend(s)   Sunny           80   6PM
# 6  No Urgent Place  Friend(s)   Sunny           55   2PM
# 7  No Urgent Place     Kid(s)   Sunny           80  10AM
# 8  No Urgent Place     Kid(s)   Sunny           80  10AM
# 9  No Urgent Place     Kid(s)   Sunny           80  10AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df1.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min',
#        'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same',
#        'direction_opp', 'Y', 'income_encoded', 'temperature_scaled'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1['destination_encoded'] = le.fit_transform(df1['destination'])
df1['passanger_encoded'] = le.fit_transform(df1['passanger'])
df1['weather_encoded'] = le.fit_transform(df1['weather'])
df1['time_encoded'] = le.fit_transform(df1['time'])
df1['coupon_encoded'] = le.fit_transform(df1['coupon'])
df1['expiration_encoded'] = le.fit_transform(df1['expiration'])
df1['gender_encoded'] = le.fit_transform(df1['gender'])
df1['age_encoded'] = oe.fit_transform(df1[['age']])
df1['maritalStatus_encoded'] = le.fit_transform(df1['maritalStatus'])
df1['education_encoded'] = le.fit_transform(df1['education'])
df1['occupation_encoded'] = le.fit_transform(df1['occupation'])
df1['Bar_encoded'] = oe.fit_transform(df1[['Bar']])
df1['CoffeeHouse_encoded'] = oe.fit_transform(df1[['CoffeeHouse']])
df1['CarryAway_encoded'] = oe.fit_transform(df1[['CarryAway']])
df1['RestaurantLessThan20_encoded'] = oe.fit_transform(df1[['RestaurantLessThan20']])
df1['Restaurant20To50_encoded'] = oe.fit_transform(df1[['Restaurant20To50']])

# %%
df1.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min',
#        'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same',
#        'direction_opp', 'Y', 'income_encoded', 'temperature_scaled',
#        'destination_encoded', 'passanger_encoded', 'weather_encoded',
#        'time_encoded', 'coupon_encoded', 'expiration_encoded',
#        'gender_encoded', 'age_encoded', 'maritalStatus_encoded',
#        'education_encoded', 'occupation_encoded', 'Bar_encoded',
#        'CoffeeHouse_encoded', 'CarryAway_encoded',
#        'RestaurantLessThan20_encoded', 'Restaurant20To50_encoded'],
#       dtype='object')

# %%
X = df1[['income_encoded', 'temperature_scaled',
       'destination_encoded', 'passanger_encoded', 'weather_encoded',
       'time_encoded', 'coupon_encoded', 'expiration_encoded',
       'gender_encoded', 'age_encoded', 'maritalStatus_encoded',
       'education_encoded', 'occupation_encoded', 'Bar_encoded',
       'CoffeeHouse_encoded', 'CarryAway_encoded',
       'RestaurantLessThan20_encoded', 'Restaurant20To50_encoded','toCoupon_GEQ5min',
       'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same',
       'direction_opp', 'has_children']]
Y = df1['Y']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred1 = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy_score(Y_test, Y_pred1)
# Out:
# 0.7490803993694167

# %%
f1_score(Y_test, Y_pred1)
# Out:
# 0.7869730091456614

# %%
precision_score(Y_test, Y_pred1)
# Out:
# 0.7587096774193548

# %%
recall_score(Y_test, Y_pred1)
# Out:
# 0.8174235403151066
